# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
url = "https://gihyo.jp/"

# %%
response = requests.get(url)

# %%
response.text[:500]
# Out:
# '<!DOCTYPE html>\r\n<html lang="ja">\r\n<head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb#">\r\n<meta http-equiv="Content-Type" content="text/html; charset=UTF-8" />\r\n<title>トップページ｜gihyo.jp … 技術評論社</title>\r\n<meta name="description" content="技術評論社提供のIT関連コンテンツサイト" />\r\n<meta name="keywords" content="技術評論社,gihyo.jp," />\r\n<meta name="viewport" content="width=device-width, initial-scale=1.0" />\r\n<meta http-equiv="Content-Script-Type" content="text/javascript" />\r\n<meta http-equiv="Content-Style-Typ'

# %%
response.text
# Out:
# '<!DOCTYPE html>\r\n<html lang="ja">\r\n<head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb#">\r\n<meta http-equiv="Content-Type" content="text/html; charset=UTF-8" />\r\n<title>トップページ｜gihyo.jp … 技術評論社</title>\r\n<meta name="description" content="技術評論社提供のIT関連コンテンツサイト" />\r\n<meta name="keywords" content="技術評論社,gihyo.jp," />\r\n<meta name="viewport" content="width=device-width, initial-scale=1.0" />\r\n<meta http-equiv="Content-Script-Type" content="text/javascript" />\r\n<meta http-equiv="Content-Style-Type" content="text/css" />\r\n<meta name="twitter:card" content="summary_large_image"/>\r\n<meta name="twitter:site" content="@gihyojp"/>\r\n<meta property="og:title" content="トップページ" />\r\n<meta property="og:type" content="website" />\r\n<meta property="og:description" content="技術評論社提供のIT関連コンテンツサイト" />\r\n<meta property="og:url" content="https://gihyo.jp/" />\r\n<meta property="og:image" content="https://image.gihyo.co.jp/assets/images/logo.png" />\r\n<meta property="og:site_name" content="gihyo.jp" />\r\n<meta property="fb:app_id" content="185201618169441" />\r\n\r\n\r\n<base href="/" />\r\n<link rel="canonical" href="https://gihyo.jp/" />\r\n<link rel="icon" href="/favicon.ico" type="image/x-icon" /><link rel="icon" href="/favicon.svg" size="any" type="image/svg+xml" />\r\n<link rel="publisher" href="https://plus.google.com/113010907831932672815" />\r\n<link rel="alternate" type="application/rss+xml" title="gihyo.jp RSS1.0" href="http://gihyo.jp/feed/rss1" />\r\n<link rel="alternate" type="application/rss+xml" title="gihyo.jp RSS2.0" href="http://gihyo.jp/feed/rss2" />\r\n<link rel="alternate" type="application/atom+xml" title="gihyo.jp Atom" href="http://gihyo.jp/feed/atom" />\r\n<!--[if lt IE 9]>\r\n<script src="//ie7-js.googlecode.com/svn/version/2.1(beta4)/IE9.js"></script>\r\n<![endif]-->\r\n<style>*{font-size:100%;list-style:none;margin:0;padding:0}@font-face{font-family:"gihyojp";src:local("Hiragino Sans"),local("BIZ UDゴシック"),local("メイリオ")}@font-face{font-family:"gihyojp";src:local(-apple-system),local(BlinkMacSystemFont),local("Segoe UI"),local("Roboto"),local("Ubuntu"),local(system-ui);unicode-range:U+0000-05C7}body{color:#333;font-family:gihyojp,sans-serif;font-size:12px;line-height:1.4;text-align:center;-webkit-text-autospace:ideograph-numeric ideograph-alpha;-moz-text-autospace:ideograph-numeric ideograph-alpha;-ms-text-autospace:ideograph-numeric ideograph-alpha;text-autospace:ideograph-numeric ideograph-alpha}a{color:#05C;text-decoration:none;word-wrap:break-word}a:visited{color:#3388cc}.clearfix{display:block}.clearfix:after{clear:both;content:"";display:block;height:0}img{border:none;vertical-align:top;-ms-interpolation-mode:bicubic}#wrapper{position:relative;width:985px;margin:0 auto;text-align:left}#header{position:relative;-webkit-text-size-adjust:100%;-ms-interpolation-mode:bicubic}#header:after{clear:both;content:\'\';display:block;height:0}#header #logo{padding:22px 0}#header #logo a{display:inline-block}#header .utility{border-top:3px solid #0068B7;position:absolute;right:0;top:0}#header ul{display:block;float:left;left:0px;padding-top:22px;top:0px}#header ul li{border-collapse:separate;display:block;float:left;height:21px;width:auto}#header ul li a{display:block;-webkit-font-feature-settings:\'kern\',\'liga\',\'pwid\';-moz-font-feature-settings:\'kern\',\'liga\',\'pwid\';font-feature-settings:\'kern\',\'liga\',\'pwid\';height:21px;text-rendering:optimizelegibility}#header #shortcut li a{background:transparent url(...) no-repeat 15px center;background-size:auto 5px;color:#333;display:block;font-size:11px;font-weight:bold;line-height:21px;padding:0 15px 0 22px;white-space:nowrap;width:auto}#header #searchForm{background:url(data:image/png;base64,...) no-repeat 0 26px;background-size:auto 12px;display:block;float:left;height:20px;margin-left:15px;padding-top:20px;padding-left:15px;width:auto}#header #searchForm #searchFormKeyword{background:#FFF;border:1px solid #CCC;border-radius:2px;-moz-box-si ...

# %%
response.headers
# Out:
# {'Date': 'Mon, 10 Jan 2022 03:43:49 GMT', 'Content-Type': 'text/html; charset=UTF-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Vary': 'Accept-Encoding', 'P3P': 'CP="NOI NID ADMa OUR IND UNI COM NAV"', 'X-FRAME-OPTIONS': 'SAMEORIGIN', 'X-XSS-Protection': '1; mode=block', 'Content-Encoding': 'gzip', 'CF-Cache-Status': 'DYNAMIC', 'Expect-CT': 'max-age=604800, report-uri="https://report-uri.cloudflare.com/cdn-cgi/beacon/expect-ct"', 'Server': 'cloudflare', 'CF-RAY': '6cb2e73e2a5b8351-KIX', 'alt-svc': 'h3=":443"; ma=86400, h3-29=":443"; ma=86400, h3-28=":443"; ma=86400, h3-27=":443"; ma=86400'}

# %%
for key,value in response.headers.items():
    print(key,"   ",value)
# Out:
# Date     Mon, 10 Jan 2022 03:43:49 GMT
# Content-Type     text/html; charset=UTF-8
# Transfer-Encoding     chunked
# Connection     keep-alive
# Vary     Accept-Encoding
# P3P     CP="NOI NID ADMa OUR IND UNI COM NAV"
# X-FRAME-OPTIONS     SAMEORIGIN
# X-XSS-Protection     1; mode=block
# Content-Encoding     gzip
# CF-Cache-Status     DYNAMIC
# Expect-CT     max-age=604800, report-uri="https://report-uri.cloudflare.com/cdn-cgi/beacon/expect-ct"
# Server     cloudflare
# CF-RAY     6cb2e73e2a5b8351-KIX
# alt-svc     h3=":443"; ma=86400, h3-29=":443"; ma=86400, h3-28=":443"; ma=86400, h3-27=":443"; ma=86400

# %%
response.encoding
# Out:
# 'UTF-8'

# %%
response.content[:500]
# Out:
# b'<!DOCTYPE html>\r\n<html lang="ja">\r\n<head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb#">\r\n<meta http-equiv="Content-Type" content="text/html; charset=UTF-8" />\r\n<title>\xe3\x83\x88\xe3\x83\x83\xe3\x83\x97\xe3\x83\x9a\xe3\x83\xbc\xe3\x82\xb8\xef\xbd\x9cgihyo.jp \xe2\x80\xa6 \xe6\x8a\x80\xe8\xa1\x93\xe8\xa9\x95\xe8\xab\x96\xe7\xa4\xbe</title>\r\n<meta name="description" content="\xe6\x8a\x80\xe8\xa1\x93\xe8\xa9\x95\xe8\xab\x96\xe7\xa4\xbe\xe6\x8f\x90\xe4\xbe\x9b\xe3\x81\xaeIT\xe9\x96\xa2\xe9\x80\xa3\xe3\x82\xb3\xe3\x83\xb3\xe3\x83\x86\xe3\x83\xb3\xe3\x83\x84\xe3\x82\xb5\xe3\x82\xa4\xe3\x83\x88" />\r\n<meta name="keywords" content="\xe6\x8a\x80\xe8\xa1\x93\xe8\xa9\x95\xe8\xab\x96\xe7\xa4\xbe,gihyo.jp," />\r\n<meta name="viewport" content="width=device-width, initial-scale=1.0" />\r\n<meta http-equiv="Content-Script'

# %%
soup = BeautifulSoup(response.text,"html.parser")

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="ja">
#  <head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb#">
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <title>
#    トップページ｜gihyo.jp … 技術評論社
#   </title>
#   <meta content="技術評論社提供のIT関連コンテンツサイト" name="description"/>
#   <meta content="技術評論社,gihyo.jp," name="keywords"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <meta content="text/javascript" http-equiv="Content-Script-Type"/>
#   <meta content="text/css" http-equiv="Content-Style-Type"/>
#   <meta content="summary_large_image" name="twitter:card"/>
#   <meta content="@gihyojp" name="twitter:site"/>
#   <meta content="トップページ" property="og:title"/>
#   <meta content="website" property="og:type"/>
#   <meta content="技術評論社提供のIT関連コンテンツサイト" property="og:description"/>
#   <meta content="https://gihyo.jp/" property="og:url"/>
#   <meta content="https://image.gihyo.co.jp/assets/images/logo.png" property="og:image"/>
#   <meta content="gihyo.jp" property="og:site_name"/>
#   <meta content="185201618169441" property="fb:app_id"/>
#   <base href="/"/>
#   <link href="https://gihyo.jp/" rel="canonical"/>
#   <link href="/favicon.ico" rel="icon" type="image/x-icon"/>
#   <link href="/favicon.svg" rel="icon" size="any" type="image/svg+xml"/>
#   <link href="https://plus.google.com/113010907831932672815" rel="publisher"/>
#   <link href="http://gihyo.jp/feed/rss1" rel="alternate" title="gihyo.jp RSS1.0" type="application/rss+xml"/>
#   <link href="http://gihyo.jp/feed/rss2" rel="alternate" title="gihyo.jp RSS2.0" type="application/rss+xml"/>
#   <link href="http://gihyo.jp/feed/atom" rel="alternate" title="gihyo.jp Atom" type="application/atom+xml"/>
#   <!--[if lt IE 9]>
# <script src="//ie7-js.googlecode.com/svn/version/2.1(beta4)/IE9.js"></script>
# <![endif]-->
#   <style>
#    *{font-size:100%;list-style:none;margin:0;padding:0}@font-face{font-family:"gihyojp";src:local("Hiragino Sans"),local("BIZ UDゴシック"),local("メイリオ")}@font-face{font-family:"gihyojp";src:local(-apple-system),local(BlinkMacSystemFont),local("Segoe UI"),local("Roboto"),local("Ubuntu"),local(system-ui);unicode-range:U+0000-05C7}body{color:#333;font-family:gihyojp,sans-serif;font-size:12px;line-height:1.4;text-align:center;-webkit-text-autospace:ideograph-numeric ideograph-alpha;-moz-text-autospace:ideograph-numeric ideograph-alpha;-ms-text-autospace:ideograph-numeric ideograph-alpha;text-autospace:ideograph-numeric ideograph-alpha}a{color:#05C;text-decoration:none;word-wrap:break-word}a:visited{color:#3388cc}.clearfix{display:block}.clearfix:after{clear:both;content:"";display:block;height:0}img{border:none;vertical-align:top;-ms-interpolation-mode:bicubic}#wrapper{position:relative;width:985px;margin:0 auto;text-align:left}#header{position:relative;-webkit-text-size-adjust:100%;-ms-interpolation-mode:bicubic}#header:after{clear:both;content:'';display:block;height:0}#header #logo{padding:22px 0}#header #logo a{display:inline-block}#header .utility{border-top:3px solid #0068B7;position:absolute;right:0;top:0}#header ul{display:block;float:left;left:0px;padding-top:22px;top:0px}#header ul li{border-collapse:separate;display:block;float:left;height:21px;width:auto}#header ul li a{display:block;-webkit-font-feature-settings:'kern','liga','pwid';-moz-font-feature-settings:'kern','liga','pwid';font-feature-settings:'kern','liga','pwid';height:21px;text-rendering:optimizelegibility}#header #shortcut li a{background:transparent url(...) no-repeat 15px center;background-size:auto 5px;color:#333;display:block;font-size:11px;font-weight:bold;line-height:21px;padding:0 15px 0 22px;white-space:nowrap;width:auto}#header #searchForm{background:url(data:image/png;base64,...) no-repeat 0 26px;background-size:auto 12px;display:block;float:left;height:20px;margin-left:15px;padding-top:20px;padding-left:15px;width:auto}#header #searchForm #searchFormKeyword{background:#FFF;border:1px solid #CCC;border-radius:2px;-moz-box-sizing:border-box;box-sizing:border-box;font-size:12px;height:24px;line-height:2;margin-right:4px;padding:0 0.5em;position:relative;width:267px}.submitButton{background:#33A61D;border:1px solid #098a13;border-radius:2px;-moz-box-sizing:border-box;box-sizing:border-box;color:#FFF;cursor:pointer;display:block;float:right;font-weight:bold;line-height:2;padding:0 0.8em;text-align:center;text-shadow:0 0 2px #098a13;-webkit-appearance:none}#header #searchForm #searchFormSubmit{font-size:11px}#header #headerBanner01,#header #headerBanner02{margin-bottom:15px}#header #headerBanner01{float:left}#header #headerBanner02{float:right}.headCategoryNavigation{display:block;line-height:1;margin-bottom:4px;-ms-interpolation-mode:bicubic;position:relative;-webkit-text-size-adjust:100%;width:100%}.headCategoryNavigation .main{background:#0068B7;display:block;width:100%}.headCategoryNavigation .main li{float:left;display:block;height:34px;margin-top:4px;width:auto}.headCategoryNavigation .main li:first-child{margin-left:5px}.headCategoryNavigation .main .change{float:right}.headCategoryNavigation .main li a{color:#FBFBFF;display:block;-webkit-font-feature-settings:"kern", "liga", "pwid";-moz-font-feature-settings:"kern", "liga", "pwid";font-feature-settings:"kern", "liga", "pwid";font-size:12px;font-weight:bold;height:34px;line-height:30px;padding:0 20px;text-align:center;text-rendering:optimizelegibility;text-shadow:0 0 2px #144b83;width:auto}.headCategoryNavigation .main .change a{font-weight:normal;padding-left:0}.headCategoryNavigation .main .change a:before{content:'▶ ';font-size:0.5em;vertical-align:middle}#topicPath{-webkit-font-feature-settings:"kern", "liga", "palt";-moz-font-feature-settings:"kern", "liga", "palt";font-feature-settings:"kern", "liga", "palt";line-height:1;overflow:hidden;padding:0 10px 15px 10px;position:relative;text-overflo ...
#   </style>
#   <!--[if lt IE 9]>
# <script src="//ajax.googleapis.com/ajax/libs/jquery/1.11.4/jquery.min.js"></script>
# <![endif]-->
#   <!--[if gte IE 9]><!-->
#   <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.4/jquery.min.js">
#   </script>
#   <!--<![endif]-->
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-DL906V3TN7">
#   </script>
#   <script type="text/javascript">
#    var googletag = googletag || {};
# googletag.cmd = googletag.cmd || [];
# (function() {
# var gads = document.createElement('script');
# gads.async = true;
# gads.type = 'text/javascript';
# var useSSL = 'https:' == document.location.protocol;
# gads.src = (useSSL ? 'https:' : 'http:') +
# '//www.googletagservices.com/tag/js/gpt.js';
# var node = document.getElementsByTagName('script')[0];
# node.parentNode.insertBefore(gads, node);
# })();
#   </script>
#   <script defer="" type="text/javascript">
#    googletag.cmd.push(function() {
# googletag.defineSlot('/33530947/top-bigbanner', [728,90], 'div-gpt-ad-1369887592403-0').addService(googletag.pubads());
# googletag.defineSlot('/33530947/top-centertextlink1', [300,16], 'div-gpt-ad-1369887592403-2').addService(googletag.pubads());
# googletag.defineSlot('/33530947/top-centertextlink2', [300,16], 'div-gpt-ad-1369887592403-3').addService(googletag.pubads());
# googletag.defineSlot('/33530947/top-rectangle1', [300,300], 'div-gpt-ad-1369887592403-4').addService(googletag.pubads());
# googletag.defineSlot('/33530947/top-rectangle2', [300,300], 'div-gpt-ad-1369887592403-5').addService(googletag.pubads());
# googletag.defineSlot('/33530947/top-mainregularbanner', [468,60], 'div-gpt-ad-1369887592403-7').addService(googletag.pubads());
# googletag.defineSlot('/33530947/top-textlink1', [485,16], 'div-gpt-ad-1369887592403-8').addService(googletag.pubads());
# googletag.defineSlot('/33530947/top-textlink2', [485,16], 'div-gpt-ad-1369887592403-9').addService(googletag.pubads());
# googletag.defineSlot('/33530947/top-articlerectangle', [336,280], 'div-gpt-ad-1369887592403-10').addService(googletag.pubads());
# googletag.defineSlot('/33530947/top-delimiterregularbanner', [468,60], 'div-gpt-ad-1369887592403-11').addService(googletag.pubads());
# googletag.defineSlot('/33530947/top-delimiterrectangle', [300,300], 'div-gpt-ad-1369887592403-12').addService(googletag.pubads());
# googletag.defineSlot('/33530947/top-minibanner', [243,90], 'div-gpt-ad-1369887592403-13').addService(googletag.pubads());
# googletag.defineSlot('/33530947/top-smallrectangle', [300,100], 'div-gpt-ad-1369887592403-14').addService(googletag.pubads());
#
# googletag.pubads().enableSingleRequest();
# googletag.enableServices();
# });
#   </script>
#   <script defer="">
#    var textAd = function() {setTimeout(function(){
#   console.log('pri');
#   var obsPTA = new MutationObserver(function(records) {
#     records.forEach(function(recod) {
#       Array.from(recod.addedNodes).filter(function($node) {
#         if ($node.nodeName === 'IFRAME') {
#           return true;
#         }
#         return false;
#       }).forEach(function($node) {
#         if ($node.contentWindow.document.readyState === 'complete') {
#           console.log('.');
#           tadclip($node);
#           return;
#         }
#         console.log(',');
#         $node.contentWindow.document.addEventListener('DOMContentLoaded', function(){setTimeout(tadclip($node), 50)});
#         return;
#       });
#     });
#   });
#
#   var tadclip = function ($obj) {
#     var $base, $body, $style, $tmp;
#     $obj.parentNode.parentNode.style.height = 'auto';
#     $base = $obj.contentWindow.document.querySelector('html');
#     $body = $obj.contentDocument.querySelector('body');
#     if (typeof $base === 'undefined' || typeof $body === 'undefined') {
#       return;
#     }
#     $style = document.createElement('style');
#     $style.textContent = 'body{font-family:Arial,sans-serif;font-size:14px;line-height:18px;padding-top:10px}span{display:block;border-bottom:1px solid #E5E5E5;padding-bottom:10px}a{color:#05C;text-decoration:none;padding:4px 0}a span{border-bottom:none;padding-bottom:2px}b{padding:0 0 0 18px;background:url(/assets/templates/gihyojp2007/image/pr13x13.gif) 0px 0 no-repeat}a:hover{color:#38C;text-decoration:underline}body>br{display:none}';
#     $body.insertBefore($style, $body.firstChild);
#     $tmp = $body.querySelector('.GoogleActiveViewElement');
#     if (typeof $tmp === 'object' && $tmp !== null && $tmp.lastElementChild.nodeName === 'BR') {
#       $tmp.removeChild($tmp.lastElementChild);
#     }
#     $tmp.style.display = 'inline-block';
#     $tmp.style.width = '100%';
#     h = $base.offsetHeight;
#     $obj.height = h;
#     $style = void 0;
#     $tmp = void 0;
#     $body = void 0;
#     $base = void 0;
#     $obj = void 0;
#     return;
#   }
#
#   var $target = document.querySelector('#primaryTopTextPr .textAdList01, #primaryTopTextPr .textAdList02');
#   if (typeof $target === 'object' && $target !== null) {
#     $target.querySelectorAll('.is-banner').forEach(function($node){$node.style.height = '0';});
#     var $ptt = document.getElementById('primaryTopTextPr');
#     if (typeof $ptt === 'object' && $ptt !== null) {
#       $ptt.style.height = 'auto';
#       $ptt = void 0;
#     }
#
#     obsPTA.observe($target, {childList: true, subtree: true});
#     $target = void 0;
#
#     setTimeout(function(){
#       obsPTA.disconnect();
#       document.querySelectorAll('#primaryTopTextPr .is-banner > script').forEach(function($node) {
#         $node.parentNode.parentNode.removeChild($node.parentNode);
#         $node = void 0;
#       });
#     }, 5000);
#   }
# }, 50);
# setTimeout(function(){
#   console.log('sec');
#   var obsSTA = new MutationObserver(function(records) {
#     records.forEach(function(recod) {
#       Array.from(recod.addedNodes).filter(function($node) {
#         if ($node.nodeName === 'IFRAME') {
#           return true;
#         }
#         return false;
#       }).forEach(function($node) {
#         if ($node.contentWindow.document.readyState === 'complete') {
#           console.log(':');
#           ctadclip($node);
#           return;
#         }
#         console.log(';');
#         $node.contentWindow.document.addEventListener('DOMContentLoaded', function(){setTimeout(ctadclip($node), 50)});
#         return;
#       });
#     });
#   });
#
#   var ctadclip = function ($obj) {
#     var $base, $body, $style, $tmp;
#     $obj.parentNode.parentNode.style.height = 'auto';
#     $base = $obj.contentWindow.document.querySelector('html');
#     $body = $obj.contentDocument.querySelector('body');
#     if (typeof $base === 'undefined' || typeof $body === 'undefined') {
#       return;
#     }
#     $style = document.createElement('style');
#     $style.textContent = 'body{font-family:Arial,sans-serif;font-size:12px;line-height:16px;padding-top:4px;text-rendering:optimizeLegibility;-webkit-font-feature-settings:"kern","liga","palt";-moz-font-feature-settings:"kern","liga","palt";font-feature-settings:"kern","liga","palt"}span{display:block}a{color:#05C;text-decoration:none;font-size:14px;line-height:19px}b{border-bottom:none;padding-bottom:2px}b{padding:6px 0 0 15px;background:url(/assets/templates/gihyojp2007/image/bg/pr_02.gif) 0px 10px no-repeat}a:hover{color:#38C;text-decoration:underline}body>br{display:none}';
#     $body.insertBefore($style, $body.firstChild);
#     $tmp = $body.querySelector('.GoogleActiveViewElement');
#     if (typeof $tmp === 'object' && $tmp !== null && $tmp.lastElementChild.nodeName === 'BR') {
#       $tmp.removeChild($tmp.lastElementChild);
#     }
#     $tmp.style.display = 'inline-block';
#     $tmp.style.width = '100%';
#     h = $base.offsetHeight;
#     $obj.height = h;
#     $style = void 0;
#     $tmp = void 0;
#     $body = void 0;
#     $base = void 0;
#     $obj = void 0;
#     return;
#   }
#
#   var $target = document.querySelector('#secondaryTopTextPr .prList01');
#   if (typeof $target === 'object' && $target !== null) {
#     $target.querySelectorAll('.is-banner').forEach(function($node){$node.style.height = '0';});
#     var $stt = document.getElementById('secondaryTopTextPr');
#     if (typeof $stt === 'object' && $stt !== null) {
#       $stt.style.height = 'auto';
#       $stt = void 0;
#     }
#
#     obsSTA.observe($target, {childList: true, subtree: true});
#     $target = void 0;
#
#     setTimeout(function(){
#       obsSTA.disconnect();
#       document.querySelectorAll('#secondaryTopTextPr .is-banner > script').forEach(function($node) {
#         $node.parentNode.parentNode.removeChild($node.parentNode);
#         $node = void 0;
#       });
#     }, 5000);
#   }
# }, 50);
# };if (document.readyState === 'complete') {textAd();} else {document.addEventListener('DOMContentLoaded', function(){textAd();});}
#   </script>
#  </head>
#  <body itemscope="" itemtype="http://schema.org/WebPage">
#   <div id="wrapper">
#    <header role="banner">
#     <div id="header" itemscope="" itemtype="http://schema.org/WPHeader">
#      <h1 id="logo">
#       <a href="/">
#        <img alt="gihyo.jp" height="27" src="/assets/templates/gihyojp2007/image/gihyojp_logo.png" width="141"/>
#       </a>
#      </h1>
#      <div class="utility">
#       <ul id="shortcut">
#        <li class="num02">
#         <a href="/site/inquiry">
#          お問い合わせ
#         </a>
#        </li>
#        <li class="num03">
#         <a href="/site/profile">
#          会社案内
#         </a>
#        </li>
#       </ul>
#       <div id="searchForm">
#        <form action="/result">
#         <input id="searchFormKeyword" name="query" type="text" value="検索したい用語を入力"/>
#         <input class="submitButton" id="searchFormSubmit" type="submit" value="検索"/>
#        </form>
#       </div>
#      </div>
#      <div id="headerBanner01">
#       <div class="is-banner" id="div-gpt-ad-1369887592403-0" style="min-width:728px; min-height:90px; margin:0 auto">
#        <script type="text/javascript">
#         googletag.cmd.push(function() { googletag.display('div-gpt-ad-1369887592403-0'); });
#        </script>
#       </div>
#      </div>
#      <div id="headerBanner02">
#       <div class="is-banner" id="div-gpt-ad-1369887592403-13" style="min-width:243px; min-height:90px; margin:0 auto">
#        <script type="text/javascript">
#         googletag.cmd.push(function() { googletag.display('div-gpt-ad-1369887592403-13'); });
#        </script>
#       </div>
#      </div>
#     </div>
#     <div class="headCategoryNavigation" id="categoryNavigation">
#      <ul class="main clearfix">
#       <li>
#        <a href="/dev" title="DEVELOPER STAGE">
#         デベロッパ
#        </a>
#       </li>
#       <li>
#        <a href="/admin" title="ADMINISTRATOR STAGE">
#         アドミニストレータ
#        </a>
#       </li>
#       <li>
#        <a href="/design" title="WEB+DESIGN STAGE">
#         WEB＋デザイン
#        </a>
#       </li>
#       <li>
#        <a href="/lifestyle" title="LIFESTYLE STAGE">
#         ライフスタイル
#        </a>
#       </li>
#       <li class="change">
#        <a href="/book" title="書籍案内">
#         書籍案内
#        </a>
#       </li>
#       <li class="change">
#        <a href="https://gihyo.jp/dp" title="Gihyo Digital Publishing">
#         電子書籍
#        </a>
#       </li>
#       <li class="change">
#        <a href="https://direct.gihyo.jp" title="Gihyo Direct">
#         直販
#        </a>
#       </li>
#      </ul>
#     </div>
#     <div id="topicPath" itemprop="breadcrumb">
#      <span class="B_crumbBox">
#       <span class="B_currentCrumb">
#        トップページ
#       </span>
#      </span>
#     </div>
#    </header>
#    <div class="clearfix" id="content">
#     <div id="main">
#      <article role="main">
#       <div id="primary">
#        <div class="sectionBlock01" id="featureArticle">
#         <h2>
#          おすすめ記事
#         </h2>
#         <dl class="featureList01">
#          <dt>
#           <a href="/dev/serial/01/china-oss-frontline">
#            <img alt="日本人が知らない中国オープンソース最前線 ―「嫌儲」「原理主義」のないOSS文化を読み解く" height="13" src="/assets/images/ICON/2021/thumb/TH13_1857_china-oss-frontline.png" title="日本人が知らない中国オープンソース最前線 ―「嫌儲」「原理主義」のないOSS文化を読み解く" width="13"/>
#           </a>
#           <a href="/dev/serial/01/china-oss-frontline">
#            日本人が知らない中国オープンソース最前線 ―「嫌儲」「原理主義」のないOSS文化を読み解く
#           </a>
#          </dt>
#          <dd class="lead clearfix">
#           <p class="data2">
#            このところ各種OSSプロジェクトに大きく貢献を広げている中国。知られざる中国のOSS最新事情を，中国在住でオープンソース活動にも加わっている著者がさまざまな観点から紹介します。
#           </p>
#          </dd>
#          <dt>
#           <a href="/lifestyle/column/01/workstyle/2021/07/2701">
#            <img alt="ゲームプランナーを目指すすべての人に伝えたい就職事情" height="18" src="/assets/images/cover/2019/thumb/TH13_9784297105129.jpg" title="ゲームプランナーを目指すすべての人に伝えたい就職事情" width="13"/>
#           </a>
#           <a href="/lifestyle/column/01/workstyle/2021/07/2701">
#            ゲームプランナーを目指すすべての人に伝えたい就職事情
#           </a>
#          </dt>
#          <dd class="lead clearfix">
#           <p class="data2">
#            ゲームプランナーってそもそもどんな仕事なのか？ゲームプランナーになるための就活ってどんななの？ 「ゲームプランナー」を目指している人に向けて，最新のゲーム業界の就職事情についてお話をしたいと思います。
#           </p>
#          </dd>
#          <dt>
#           <a href="/news/interview/01/ml_engineer">
#            <img alt="『機械学習を解釈する技術』＆『施策デザインのための機械学習入門』著者陣によるクロストーク" height="13" src="/assets/images/ICON/2021/thumb/TH13_1856_closstolk_book210727.png" title="『機械学習を解釈する技術』＆『施策デザインのための機械学習入門』著者陣によるクロストーク" width="13"/>
#           </a>
#           <a href="/news/interview/01/ml_engineer">
#            『機械学習を解釈する技術』＆『施策デザインのための機械学習入門』著者陣によるクロストーク
#           </a>
#          </dt>
#          <dd class="lead clearfix">
#           <p class="data2">
#            2021年8月に発売される『機械学習を解釈する技術』の著者である森下光之助氏と，『施策デザインのための機械学習入門』を共著した齋藤優太氏，安井翔太氏の3人が集まり，執筆の経緯や書籍への想いについて語りました。
#           </p>
#          </dd>
#         </dl>
#         <div id="primaryTopTextPr" style="height: 0">
#          <dl class="textAdList02">
#           <div class="is-banner" id="div-gpt-ad-1369887592403-8" style="min-width:485px; min-height:auto">
#            <script type="text/javascript">
#             googletag.cmd.push(function() { googletag.display('div-gpt-ad-1369887592403-8'); });
#            </script>
#           </div>
#           <div class="is-banner" id="div-gpt-ad-1369887592403-9" style="min-width:485px; min-height:auto">
#            <script type="text/javascript">
#             googletag.cmd.push(function() { googletag.display('div-gpt-ad-1369887592403-9'); });
#            </script>
#           </div>
#          </dl>
#         </div>
#        </div>
#        <div class="primaryBanner" id="centerBanner">
#         <div class="is-banner" id="div-gpt-ad-1369887592403-7" style="min-width:468px; min-height:60px; margin:0 auto">
#          <script type="text/javascript">
#           googletag.cmd.push(function() { googletag.display('div-gpt-ad-1369887592403-7'); });
#          </script>
#         </div>
#        </div>
#        <div class="sectionBlock01" id="latestArticle">
#         <h2>
#          最新記事
#         </h2>
#         <h3 class="updateDay">
#          1月7日（金）
#         </h3>
#         <dl class="dateDefinitionList02">
#          <dt>
#           <a href="/dev" title="DEVELOPER STAGE">
#            <img alt="DEVELOPER STAGE" height="13" src="/assets/templates/gihyojp2007/image/logo_icon_dev.gif" width="13"/>
#           </a>
#           <a href="/dev/serial/01/readers-forum">
#            はまちちゃんとわかばちゃんのREADER'S FORUM―読者のページ
#           </a>
#          </dt>
#          <dd class="lead clearfix">
#           <h3>
#            <a href="/dev/serial/01/readers-forum/vol126">
#             WEB+DB PRESS Vol.125へのお便り
#            </a>
#           </h3>
#           <p class="data2">
#            こんにちはこんにちは!! めっきり寒くなりましたね。秋や冬の夜長にはやっぱり読書がはかどります。そんなわけで自分はAmazonのセールでKindle Fireの8インチタブレットを買いました。
#           </p>
#           <div class="logo">
#            <a href="/dev/serial/01/readers-forum">
#             <img alt="はまちちゃんとわかばちゃんのREADER'S FORUM―読者のページ" class="lazyload" data-src="/assets/images/ICON/2009/thumb/TH64_384_readersforum.png" data-srcset="/assets/images/ICON/2009/thumb/TH64_384_readersforum.png 1x, /assets/images/ICON/2009/thumb/TH128_384_readersforum.png 2x" height="64" src="/assets/images/reading.gif" title="はまちちゃんとわかばちゃんのREADER'S FORUM―読者のページ" width="64">
#              <noscript>
#               <img alt="はまちちゃんとわかばちゃんのREADER'S FORUM―読者のページ" height="64" src="/assets/images/ICON/2009/thumb/TH64_384_readersforum.png" title="はまちちゃんとわかばちゃんのREADER'S FORUM―読者のページ" width="64"/>
#              </noscript>
#             </img>
#            </a>
#           </div>
#          </dd>
#         </dl>
#         <div class="adBannerTop" id="listBanner1">
#          <div class="is-banner" id="div-gpt-ad-1369887592403-11" style="min-width:468px; min-height:60px; margin:0 auto">
#           <script type="text/javascript">
#            googletag.cmd.push(function() { googletag.display('div-gpt-ad-1369887592403-11'); });
#           </script>
#          </div>
#         </div>
#         <h3 class="updateDay">
#          1月6日（木）
#         </h3>
#         <dl class="dateDefinitionList02">
#          <dt>
#           <a href="/admin" title="ADMINISTRATOR STAGE">
#            <img alt="ADMINISTRATOR STAGE" height="13" src="/assets/templates/gihyojp2007/image/logo_icon_admin.gif" width="13"/>
#           </a>
#           <a href="/admin/clip/01/linux_dt">
#            Linux Daily Topics
#           </a>
#          </dt>
#          <dd class="lead clearfix">
#           <h3>
#            <a href="/admin/clip/01/linux_dt/202201/06">
#             2022年1月6日　メモリ管理機能の「CleanCache」，
#             <wbr/>
#             Linuxメインラインから削除へ
#            </a>
#           </h3>
#           <p class="data2">
#            LinuxカーネルメンテナーのStephen Rothwellは1月5日，開発版カーネルのGitリポジトリ「linux-next」から，メモリ管理機能「CleanCache」に関連するコードを削除した。
#           </p>
#           <div class="logo">
#            <a href="/admin/clip/01/linux_dt">
#             <img alt="Linux Daily Topics" class="lazyload" data-src="/assets/images/ICON/2009/thumb/TH64_489_Linux_Daily_Topics.png" data-srcset="/assets/images/ICON/2009/thumb/TH64_489_Linux_Daily_Topics.png 1x, /assets/images/ICON/2009/thumb/TH128_489_Linux_Daily_Topics.png 2x" height="64" src="/assets/images/reading.gif" title="Linux Daily Topics" width="64">
#              <noscript>
#               <img alt="Linux Daily Topics" height="64" src="/assets/images/ICON/2009/thumb/TH64_489_Linux_Daily_Topics.png" title="Linux Daily Topics" width="64"/>
#              </noscript>
#             </img>
#            </a>
#           </div>
#          </dd>
#          <dt>
#           <a href="/lifestyle" title="LIFESTYLE STAGE">
#            <img alt="LIFESTYLE STAGE" height="13" src="/assets/templates/gihyojp2007/image/logo_icon_lifestyle.gif" width="13"/>
#           </a>
#           <a href="/lifestyle/clip/01/monthly-cat">
#            帰ってきた『技評ねこ部通信』
#           </a>
#          </dt>
#          <dd class="lead clearfix">
#           <h3>
#            <a href="/lifestyle/clip/01/monthly-cat/202201/0106">
#             2022年1月6日　とっくに明けておりますが・・・
#            </a>
#           </h3>
#           <p class="data2">
#            2022年トラ柄年の始まりです。
#           </p>
#           <div class="logo">
#            <a href="/lifestyle/clip/01/monthly-cat">
#             <img alt="帰ってきた『技評ねこ部通信』" class="lazyload" data-src="/assets/images/ICON/2019/thumb/TH64_1729_neko2019.jpg" data-srcset="/assets/images/ICON/2019/thumb/TH64_1729_neko2019.jpg 1x, /assets/images/ICON/2019/thumb/TH128_1729_neko2019.jpg 2x" height="64" src="/assets/images/reading.gif" title="帰ってきた『技評ねこ部通信』" width="64">
#              <noscript>
#               <img alt="帰ってきた『技評ねこ部通信』" height="64" src="/assets/images/ICON/2019/thumb/TH64_1729_neko2019.jpg" title="帰ってきた『技評ねこ部通信』" width="64"/>
#              </noscript>
#             </img>
#            </a>
#           </div>
#          </dd>
#          <dt>
#           <a href="/dev" title="DEVELOPER STAGE">
#            <img alt="DEVELOPER STAGE" height="13" src="/assets/templates/gihyojp2007/image/logo_icon_dev.gif" width="13"/>
#           </a>
#           <a href="/dev/serial/01/oss-db-various-news">
#            OSSデータベース取り取り時報
#           </a>
#          </dt>
#          <dd class="lead clearfix">
#           <h3>
#            <a href="/dev/serial/01/oss-db-various-news/0077">
#             第77回　2021年北東アジアOSS貢献者賞と，
#             <wbr/>
#             MySQL ＆ PostgreSQLの2021年の主なニュース
#            </a>
#           </h3>
#           <p class="data2">
#            この連載はOSSコンソーシアム データベース部会のメンバーがオープンソースデータベースの毎月の出来事をお伝えしています。
#           </p>
#           <div class="logo">
#            <a href="/dev/serial/01/oss-db-various-news">
#             <img alt="OSSデータベース取り取り時報" class="lazyload" data-src="/assets/images/ICON/2015/thumb/TH64_1433_oss-db-various-news.png" data-srcset="/assets/images/ICON/2015/thumb/TH64_1433_oss-db-various-news.png 1x, /assets/images/ICON/2015/thumb/TH128_1433_oss-db-various-news.png 2x" height="64" src="/assets/images/reading.gif" title="OSSデータベース取り取り時報" width="64">
#              <noscript>
#               <img alt="OSSデータベース取り取り時報" height="64" src="/assets/images/ICON/2015/thumb/TH64_1433_oss-db-various-news.png" title="OSSデータベース取り取り時報" width="64"/>
#              </noscript>
#             </img>
#            </a>
#           </div>
#          </dd>
#          <dt>
#           <a href="/design" title="WEB+DESIGN STAGE">
#            <img alt="WEB+DESIGN STAGE" height="13" src="/assets/templates/gihyojp2007/image/logo_icon_design.gif" width="13"/>
#           </a>
#           <a href="/design/clip/01/weekly-web-tech">
#            週刊Webテク通信
#           </a>
#          </dt>
#          <dd class="lead clearfix">
#           <h3>
#            <a href="/design/clip/01/weekly-web-tech/202201/06">
#             2022年1月第1週号 1位は，
#             <wbr/>
#             ソーシャルプルーフ（社会的証明）をWebサイトにどうデザインするか，
#             <wbr/>
#             気になるネタは，
#             <wbr/>
#             Web3企業のURL末尾でみかける「.xyz」とは？
#            </a>
#           </h3>
#           <p class="data2">
#            ネットで見かけたWebテク（Webテクニック・Webテクノロジー）記事から，Webデザイナーの目で厳選したネタを週刊で紹介するこのコーナー。今回は，2021年12月20日～2022年1月2日の間に見つけた記事のベスト5です。
#           </p>
#           <div class="logo">
#            <a href="/design/clip/01/weekly-web-tech">
#             <img alt="週刊Webテク通信" class="lazyload" data-src="/assets/images/ICON/2021/thumb/TH64_1842_weekly-webtech3.png" data-srcset="/assets/images/ICON/2021/thumb/TH64_1842_weekly-webtech3.png 1x, /assets/images/ICON/2021/thumb/TH128_1842_weekly-webtech3.png 2x" height="64" src="/assets/images/reading.gif" title="週刊Webテク通信" width="64">
#              <noscript>
#               <img alt="週刊Webテク通信" height="64" src="/assets/images/ICON/2021/thumb/TH64_1842_weekly-webtech3.png" title="週刊Webテク通信" width="64"/>
#              </noscript>
#             </img>
#            </a>
#           </div>
#          </dd>
#          <dt>
#           <a href="/news" title="NEWS &amp; REPORT">
#            <img alt="NEWS &amp; REPORT" height="13" src="/assets/templates/gihyojp2007/image/logo_icon_news.gif" width="13"/>
#           </a>
#           <a href="/news/info">
#            インフォメーション
#           </a>
#          </dt>
#          <dd>
#           <h3>
#            <a href="/news/info/2022/01/0601">
#             九州発Pythonイベント「PyCon Kyushu 2022 Kumamoto」1/
#             <wbr/>
#             22に開催
#            </a>
#           </h3>
#          </dd>
#         </dl>
#         <div class="adBannerTop" id="listBanner2">
#          <div class="is-banner" id="div-gpt-ad-1369887592403-12" style="min-width:300px; min-height:250px; margin:0 auto">
#           <script type="text/javascript">
#            googletag.cmd.push(function() { googletag.display('div-gpt-ad-1369887592403-12'); });
#           </script>
#          </div>
#         </div>
#         <h3 class="updateDay">
#          1月5日（水）
#         </h3>
#         <dl class="dateDefinitionList02">
#          <dt>
#           <a href="/admin" title="ADMINISTRATOR STAGE">
#            <img alt="ADMINISTRATOR STAGE" height="13" src="/assets/templates/gihyojp2007/image/logo_icon_admin.gif" width="13"/>
#           </a>
#           <a href="/admin/column/newyear">
#            新春特別企画
#           </a>
#          </dt>
#          <dd class="lead clearfix">
#           <h3>
#            <a href="/admin/column/newyear/2022/quantum-computing">
#             “Quantum Ready”のその先へ ―2022年・
#             <wbr/>
#             量子コンピューティングの可能性
#            </a>
#           </h3>
#           <p class="data2">
#            2022年を迎えた今，量子コンピューティングのトレンドを中心に，国内外の事例も織り交ぜながら，"Quantum Ready"の先に拡がる世界を覗いてみたいと思います。
#           </p>
#           <div class="logo">
#            <a href="/admin/column/newyear/2022/quantum-computing">
#             <img alt="“Quantum Ready”のその先へ ―2022年・量子コンピューティングの可能性" class="lazyload" data-src="/assets/images/ICON/2022/thumb/TH64_1868_2022admin.png" data-srcset="/assets/images/ICON/2022/thumb/TH64_1868_2022admin.png 1x, /assets/images/ICON/2022/thumb/TH128_1868_2022admin.png 2x" height="64" src="/assets/images/reading.gif" title="“Quantum Ready”のその先へ ―2022年・量子コンピューティングの可能性" width="64">
#              <noscript>
#               <img alt="“Quantum Ready”のその先へ ―2022年・量子コンピューティングの可能性" height="64" src="/assets/images/ICON/2022/thumb/TH64_1868_2022admin.png" title="“Quantum Ready”のその先へ ―2022年・量子コンピューティングの可能性" width="64"/>
#              </noscript>
#             </img>
#            </a>
#           </div>
#          </dd>
#          <dt>
#           <a href="/admin" title="ADMINISTRATOR STAGE">
#            <img alt="ADMINISTRATOR STAGE" height="13" src="/assets/templates/gihyojp2007/image/logo_icon_admin.gif" width="13"/>
#           </a>
#           <a href="/admin/serial/01/ubuntu-recipe">
#            Ubuntu Weekly Recipe
#           </a>
#          </dt>
#          <dd class="lead clearfix">
#           <h3>
#            <a href="/admin/serial/01/ubuntu-recipe/0698">
#             第698回　デスクトップ環境の2021-2022年
#            </a>
#           </h3>
#           <p class="data2">
#            新しい年の始めに，Ubuntuで使用できるさまざまなデスクトップ環境について2021年に起こったことと2022年に起こりそうなことを紹介します。
#           </p>
#           <div class="logo">
#            <a href="/admin/serial/01/ubuntu-recipe/0698">
#             <img alt="第698回　デスクトップ環境の2021-2022年" class="lazyload" data-src="/assets/images/ICON/2022/thumb/TH64_1868_2022admin.png" data-srcset="/assets/images/ICON/2022/thumb/TH64_1868_2022admin.png 1x, /assets/images/ICON/2022/thumb/TH128_1868_2022admin.png 2x" height="64" src="/assets/images/reading.gif" title="第698回　デスクトップ環境の2021-2022年" width="64">
#              <noscript>
#               <img alt="第698回　デスクトップ環境の2021-2022年" height="64" src="/assets/images/ICON/2022/thumb/TH64_1868_2022admin.png" title="第698回　デスクトップ環境の2021-2022年" width="64"/>
#              </noscript>
#             </img>
#            </a>
#           </div>
#          </dd>
#          <dt>
#           <a href="/dev" title="DEVELOPER STAGE">
#            <img alt="DEVELOPER STAGE" height="13" src="/assets/templates/gihyojp2007/image/logo_icon_dev.gif" width="13"/>
#           </a>
#           <a href="/dev/column/newyear">
#            新春特別企画
#           </a>
#          </dt>
#          <dd class="lead clearfix">
#           <h3>
#            <a href="/dev/column/newyear/2022/carbon-neutral">
#             2022年，
#             <wbr/>
#             カーボンニュートラルへの動きがソフトウェア/
#             <wbr/>
#             ITシステムの世界にやってくる
#            </a>
#           </h3>
#           <p class="data2">
#            ITにおけるグリーンやカーボンニュートラルの現状と今後の展望，2022年を迎えたいま知っておきたいことなど，現場で携わる皆さんにお話を伺いました。
#           </p>
#           <div class="logo">
#            <a href="/dev/column/newyear/2022/carbon-neutral">
#             <img alt="2022年，カーボンニュートラルへの動きがソフトウェア/ITシステムの世界にやってくる" class="lazyload" data-src="/assets/images/ICON/2022/thumb/TH64_1870_2022dev.png" data-srcset="/assets/images/ICON/2022/thumb/TH64_1870_2022dev.png 1x, /assets/images/ICON/2022/thumb/TH128_1870_2022dev.png 2x" height="64" src="/assets/images/reading.gif" title="2022年，カーボンニュートラルへの動きがソフトウェア/ITシステムの世界にやってくる" width="64">
#              <noscript>
#               <img alt="2022年，カーボンニュートラルへの動きがソフトウェア/ITシステムの世界にやってくる" height="64" src="/assets/images/ICON/2022/thumb/TH64_1870_2022dev.png" title="2022年，カーボンニュートラルへの動きがソフトウェア/ITシステムの世界にやってくる" width="64"/>
#              </noscript>
#             </img>
#            </a>
#           </div>
#          </dd>
#          <dt>
#           <a href="/dev" title="DEVELOPER STAGE">
#            <img alt="DEVELOPER STAGE" height="13" src="/assets/templates/gihyojp2007/image/logo_icon_dev.gif" width="13"/>
#           </a>
#           <a href="/dev/column/newyear">
#            新春特別企画
#           </a>
#          </dt>
#          <dd class="lead clearfix">
#           <h3>
#            <a href="/dev/column/newyear/2022/pwa-prospect">
#             Progressive Web Appsの振り返りとこれから
#            </a>
#           </h3>
#           <p class="data2">
#            今回の記事では，国内でのPWAの動向を振り返り，改めてPWA開発のスタンダードとこれからのPWAについてまとめます。
#           </p>
#           <div class="logo">
#            <a href="/dev/column/newyear/2022/pwa-prospect">
#             <img alt="Progressive Web Appsの振り返りとこれから" class="lazyload" data-src="/assets/images/ICON/2022/thumb/TH64_1870_2022dev.png" data-srcset="/assets/images/ICON/2022/thumb/TH64_1870_2022dev.png 1x, /assets/images/ICON/2022/thumb/TH128_1870_2022dev.png 2x" height="64" src="/assets/images/reading.gif" title="Progressive Web Appsの振り返りとこれから" width="64">
#              <noscript>
#               <img alt="Progressive Web Appsの振り返りとこれから" height="64" src="/assets/images/ICON/2022/thumb/TH64_1870_2022dev.png" title="Progressive Web Appsの振り返りとこれから" width="64"/>
#              </noscript>
#             </img>
#            </a>
#           </div>
#          </dd>
#          <dt>
#           <a href="/design" title="WEB+DESIGN STAGE">
#            <img alt="WEB+DESIGN STAGE" height="13" src="/assets/templates/gihyojp2007/image/logo_icon_design.gif" width="13"/>
#           </a>
#           <a href="/design/column/newyear">
#            新春特別企画
#           </a>
#          </dt>
#          <dd class="lead clearfix">
#           <h3>
#            <a href="/design/column/newyear/2022/web-accessibility-prospect">
#             2022年のWebアクセシビリティ
#            </a>
#           </h3>
#           <p class="data2">
#            あけましておめでとうございます。株式会社ミツエーリンクスの中村直樹です。昨年に引き続き，技術仕様と国内法整備に関して，2022年のWebアクセシビリティの短期的な予測をしてみます。
#           </p>
#           <div class="logo">
#            <a href="/design/column/newyear/2022/web-accessibility-prospect">
#             <img alt="2022年のWebアクセシビリティ" class="lazyload" data-src="/assets/images/ICON/2022/thumb/TH64_1869_2022design.png" data-srcset="/assets/images/ICON/2022/thumb/TH64_1869_2022design.png 1x, /assets/images/ICON/2022/thumb/TH128_1869_2022design.png 2x" height="64" src="/assets/images/reading.gif" title="2022年のWebアクセシビリティ" width="64">
#              <noscript>
#               <img alt="2022年のWebアクセシビリティ" height="64" src="/assets/images/ICON/2022/thumb/TH64_1869_2022design.png" title="2022年のWebアクセシビリティ" width="64"/>
#              </noscript>
#             </img>
#            </a>
#           </div>
#          </dd>
#          <dt>
#           <a href="/design" title="WEB+DESIGN STAGE">
#            <img alt="WEB+DESIGN STAGE" height="13" src="/assets/templates/gihyojp2007/image/logo_icon_design.gif" width="13"/>
#           </a>
#           <a href="/design/column/newyear">
#            新春特別企画
#           </a>
#          </dt>
#          <dd class="lead clearfix">
#           <h3>
#            <a href="/design/column/newyear/2022/css-prospect">
#             2022年のCSS
#            </a>
#           </h3>
#           <p class="data2">
#            昨日に続き，新春特別企画のブラウザとウェブ標準動向について紹介します。取り上げるトピックの数やそのインパクトから，今回はCSSを独立した記事として取り上げることになりました。
#           </p>
#           <div class="logo">
#            <a href="/design/column/newyear/2022/css-prospect">
#             <img alt="2022年のCSS" class="lazyload" data-src="/assets/images/ICON/2022/thumb/TH64_1869_2022design.png" data-srcset="/assets/images/ICON/2022/thumb/TH64_1869_2022design.png 1x, /assets/images/ICON/2022/thumb/TH128_1869_2022design.png 2x" height="64" src="/assets/images/reading.gif" title="2022年のCSS" width="64">
#              <noscript>
#               <img alt="2022年のCSS" height="64" src="/assets/images/ICON/2022/thumb/TH64_1869_2022design.png" title="2022年のCSS" width="64"/>
#              </noscript>
#             </img>
#            </a>
#           </div>
#          </dd>
#         </dl>
#         <h3 class="updateDay">
#          1月4日（火）
#         </h3>
#         <dl class="dateDefinitionList02">
#          <dt>
#           <a href="/design" title="WEB+DESIGN STAGE">
#            <img alt="WEB+DESIGN STAGE" height="13" src="/assets/templates/gihyojp2007/image/logo_icon_design.gif" width="13"/>
#           </a>
#           <a href="/design/column/newyear">
#            新春特別企画
#           </a>
#          </dt>
#          <dd class="lead clearfix">
#           <h3>
#            <a href="/design/column/newyear/2022/web-standards-and-browsers">
#             2022年のブラウザとウェブ標準
#            </a>
#           </h3>
#           <p class="data2">
#            2022年になりました。矢倉眞隆（@myakura）と申します。昨年に引き続き，新春特別企画のブラウザとウェブ標準を担当させていただきます。
#           </p>
#           <div class="logo">
#            <a href="/design/column/newyear/2022/web-standards-and-browsers">
#             <img alt="2022年のブラウザとウェブ標準" class="lazyload" data-src="/assets/images/ICON/2022/thumb/TH64_1869_2022design.png" data-srcset="/assets/images/ICON/2022/thumb/TH64_1869_2022design.png 1x, /assets/images/ICON/2022/thumb/TH128_1869_2022design.png 2x" height="64" src="/assets/images/reading.gif" title="2022年のブラウザとウェブ標準" width="64">
#              <noscript>
#               <img alt="2022年のブラウザとウェブ標準" height="64" src="/assets/images/ICON/2022/thumb/TH64_1869_2022design.png" title="2022年のブラウザとウェブ標準" width="64"/>
#              </noscript>
#             </img>
#            </a>
#           </div>
#          </dd>
#          <dt>
#           <a href="/dev" title="DEVELOPER STAGE">
#            <img alt="DEVELOPER STAGE" height="13" src="/assets/templates/gihyojp2007/image/logo_icon_dev.gif" width="13"/>
#           </a>
#           <a href="/dev/column/newyear">
#            新春特別企画
#           </a>
#          </dt>
#          <dd class="lead clearfix">
#           <h3>
#            <a href="/dev/column/newyear/2022/iot-tech-torends">
#             IoT活用で知っておきたい「2022年のIoT，
#             <wbr/>
#             3つのトレンド」
#            </a>
#           </h3>
#           <p class="data2">
#            Wi-FiやLTEといった通信を使って現場をデジタル化したり，遠隔からモノを操作するのが「IoT」です。
#           </p>
#           <div class="logo">
#            <a href="/dev/column/newyear/2022/iot-tech-torends">
#             <img alt="IoT活用で知っておきたい「2022年のIoT，3つのトレンド」" class="lazyload" data-src="/assets/images/ICON/2022/thumb/TH64_1870_2022dev.png" data-srcset="/assets/images/ICON/2022/thumb/TH64_1870_2022dev.png 1x, /assets/images/ICON/2022/thumb/TH128_1870_2022dev.png 2x" height="64" src="/assets/images/reading.gif" title="IoT活用で知っておきたい「2022年のIoT，3つのトレンド」" width="64">
#              <noscript>
#               <img alt="IoT活用で知っておきたい「2022年のIoT，3つのトレンド」" height="64" src="/assets/images/ICON/2022/thumb/TH64_1870_2022dev.png" title="IoT活用で知っておきたい「2022年のIoT，3つのトレンド」" width="64"/>
#              </noscript>
#             </img>
#            </a>
#           </div>
#          </dd>
#          <dt>
#           <a href="/admin" title="ADMINISTRATOR STAGE">
#            <img alt="ADMINISTRATOR STAGE" height="13" src="/assets/templates/gihyojp2007/image/logo_icon_admin.gif" width="13"/>
#           </a>
#           <a href="/admin/column/newyear">
#            新春特別企画
#           </a>
#          </dt>
#          <dd class="lead clearfix">
#           <h3>
#            <a href="/admin/column/newyear/2022/cloudnative-prospect">
#             2022年に注目したいCloudNative関連技術
#            </a>
#           </h3>
#           <p class="data2">
#            あけましておめでとうございます。サイバーエージェントの青山真也です。今年の新春企画では，2022年にも動向を見ていきたいと思っている，2021年のCloudNative関連のトピックを紹介します。
#           </p>
#           <div class="logo">
#            <a href="/admin/column/newyear/2022/cloudnative-prospect">
#             <img alt="2022年に注目したいCloudNative関連技術" class="lazyload" data-src="/assets/images/ICON/2022/thumb/TH64_1868_2022admin.png" data-srcset="/assets/images/ICON/2022/thumb/TH64_1868_2022admin.png 1x, /assets/images/ICON/2022/thumb/TH128_1868_2022admin.png 2x" height="64" src="/assets/images/reading.gif" title="2022年に注目したいCloudNative関連技術" width="64">
#              <noscript>
#               <img alt="2022年に注目したいCloudNative関連技術" height="64" src="/assets/images/ICON/2022/thumb/TH64_1868_2022admin.png" title="2022年に注目したいCloudNative関連技術" width="64"/>
#              </noscript>
#             </img>
#            </a>
#           </div>
#          </dd>
#          <dt>
#           <a href="/admin" title="ADMINISTRATOR STAGE">
#            <img alt="ADMINISTRATOR STAGE" height="13" src="/assets/templates/gihyojp2007/image/logo_icon_admin.gif" width="13"/>
#           </a>
#           <a href="/admin/clip/01/ubuntu-topics">
#            Ubuntu Weekly Topics
#           </a>
#          </dt>
#          <dd class="lead clearfix">
#           <h3>
#            <a href="/admin/clip/01/ubuntu-topics/202201/04">
#             2022年1月4日新春特別号　2021-2022年のUbuntu
#            </a>
#           </h3>
#           <p class="data2">
#            2022年のUbuntuにとってもっとも重要なイベントは，4月の22.04 LTSのリリースでしょう。GUIの基盤をXからWaylandへ切り替えた後の最初のLTSリリースであり，同時にいろいろな戦略の基盤となるリリースでもあります。
#           </p>
#           <div class="logo">
#            <a href="/admin/clip/01/ubuntu-topics/202201/04">
#             <img alt="2022年1月4日新春特別号　2021-2022年のUbuntu" class="lazyload" data-src="/assets/images/ICON/2022/thumb/TH64_1868_2022admin.png" data-srcset="/assets/images/ICON/2022/thumb/TH64_1868_2022admin.png 1x, /assets/images/ICON/2022/thumb/TH128_1868_2022admin.png 2x" height="64" src="/assets/images/reading.gif" title="2022年1月4日新春特別号　2021-2022年のUbuntu" width="64">
#              <noscript>
#               <img alt="2022年1月4日新春特別号　2021-2022年のUbuntu" height="64" src="/assets/images/ICON/2022/thumb/TH64_1868_2022admin.png" title="2022年1月4日新春特別号　2021-2022年のUbuntu" width="64"/>
#              </noscript>
#             </img>
#            </a>
#           </div>
#          </dd>
#          <dt>
#           <a href="/lifestyle" title="LIFESTYLE STAGE">
#            <img alt="LIFESTYLE STAGE" height="13" src="/assets/templates/gihyojp2007/image/logo_icon_lifestyle.gif" width="13"/>
#           </a>
#           <a href="/lifestyle/column/newyear">
#            新春特別企画
#           </a>
#          </dt>
#          <dd class="lead clearfix">
#           <h3>
#            <a href="/lifestyle/column/newyear/2022/privacy-standards">
#             2022年のプライバシー標準
#            </a>
#           </h3>
#           <p class="data2">
#            あけましておめでとうございます。@_natこと崎村夏彦です。2022年の年頭にあたり，2021年のプライバシー関連の動きを振り返り，その上で2022年を展望してみたいと思います。
#           </p>
#           <div class="logo">
#            <a href="/lifestyle/column/newyear/2022/privacy-standards">
#             <img alt="2022年のプライバシー標準" class="lazyload" data-src="/assets/images/ICON/2022/thumb/TH64_1871_2022lifestyle.png" data-srcset="/assets/images/ICON/2022/thumb/TH64_1871_2022lifestyle.png 1x, /assets/images/ICON/2022/thumb/TH128_1871_2022lifestyle.png 2x" height="64" src="/assets/images/reading.gif" title="2022年のプライバシー標準" width="64">
#              <noscript>
#               <img alt="2022年のプライバシー標準" height="64" src="/assets/images/ICON/2022/thumb/TH64_1871_2022lifestyle.png" title="2022年のプライバシー標準" width="64"/>
#              </noscript>
#             </img>
#            </a>
#           </div>
#          </dd>
#         </dl>
#         <p class="linkParagraph01">
#          <a href="contentslist">
#           記事一覧
#          </a>
#         </p>
#        </div>
#       </div>
#      </article>
#      <aside>
#       <div class="robots-nocontent" id="secondary" itemscope="" itemtype="http://schema.org/WPSideBar">
#        <div class="textPR" id="secondaryTopTextPr" style="height: 0">
#         <div class="prList01">
#          <div class="is-banner" id="div-gpt-ad-1369887592403-2" style="min-width:300px; min-height:auto">
#           <script type="text/javascript">
#            googletag.cmd.push(function() { googletag.display('div-gpt-ad-1369887592403-2'); });
#           </script>
#          </div>
#          <div class="is-banner" id="div-gpt-ad-1369887592403-3" style="min-width:300px; min-height:auto">
#           <script type="text/javascript">
#            googletag.cmd.push(function() { googletag.display('div-gpt-ad-1369887592403-3'); });
#           </script>
#          </div>
#         </div>
#        </div>
#        <div class="banner">
#         <div class="is-banner" id="div-gpt-ad-1369887592403-4" style="min-width:300px; min-height:250px; margin:0 auto">
#          <script type="text/javascript">
#           googletag.cmd.push(function() { googletag.display('div-gpt-ad-1369887592403-4'); });
#          </script>
#         </div>
#        </div>
#        <div class="sectionBlock04 clearfix" id="gdp">
#         <div class="is-banner" id="div-gpt-ad-1369887592403-14" style="min-width:300px; min-height:100px; margin:0 auto">
#          <script type="text/javascript">
#           googletag.cmd.push(function() { googletag.display('div-gpt-ad-1369887592403-14'); });
#          </script>
#         </div>
#        </div>
#        <div class="sectionBlock04 clearfix" id="gihyojpSpecial">
#         <h2>
#          ピックアップ
#         </h2>
#         <dl class="definition01">
#          <dt>
#           <a href="dev/serial/01/git-resocia">
#            ヒューマンリソシアのGITサービスが目指す，時代にアジャストするエンジニアチームの作り方
#           </a>
#          </dt>
#          <dd class="clearfix">
#           <div class="logo">
#            <a href="/dev/serial/01/git-resocia">
#             <img alt="ヒューマンリソシアのGITサービスが目指す，時代にアジャストするエンジニアチームの作り方" class="lazyload" data-src="/assets/images/ICON/2021/thumb/TH64_1843_git-resocia.png" data-srcset="/assets/images/ICON/2021/thumb/TH64_1843_git-resocia.png 1x, /assets/images/ICON/2021/thumb/TH128_1843_git-resocia.png 2x" height="64" src="/assets/images/reading.gif" title="ヒューマンリソシアのGITサービスが目指す，時代にアジャストするエンジニアチームの作り方" width="64"/>
#             <noscript>
#              <img alt="ヒューマンリソシアのGITサービスが目指す，時代にアジャストするエンジニアチームの作り方" height="64" src="/assets/images/ICON/2021/thumb/TH64_1843_git-resocia.png" title="ヒューマンリソシアのGITサービスが目指す，時代にアジャストするエンジニアチームの作り方" width="64"/>
#             </noscript>
#            </a>
#           </div>
#           <p>
#            アフターコロナにおけるエンジニアチームの作り方，グローバルな視点でのエンジニア獲得と開発とコミュニケーションの在り方について取り上げます。
#           </p>
#          </dd>
#          <dt>
#           <a href="dev/serial/01/line2021">
#            LINE テクノロジー＆エンジニアリング大全
#           </a>
#          </dt>
#          <dd class="clearfix">
#           <div class="logo">
#            <a href="/dev/serial/01/line2021">
#             <img alt="LINE テクノロジー＆エンジニアリング大全" class="lazyload" data-src="/assets/images/ICON/2021/thumb/TH64_1838_LINE2021b.jpg" data-srcset="/assets/images/ICON/2021/thumb/TH64_1838_LINE2021b.jpg 1x, /assets/images/ICON/2021/thumb/TH128_1838_LINE2021b.jpg 2x" height="64" src="/assets/images/reading.gif" title="LINE テクノロジー＆エンジニアリング大全" width="64"/>
#             <noscript>
#              <img alt="LINE テクノロジー＆エンジニアリング大全" height="64" src="/assets/images/ICON/2021/thumb/TH64_1838_LINE2021b.jpg" title="LINE テクノロジー＆エンジニアリング大全" width="64"/>
#             </noscript>
#            </a>
#           </div>
#           <p>
#            「LINE DEVELOPER DAY 2020」より，注目すべきテクノロジー，エンジニアリングをピックアップし，詳説インタビューを実施しました。
#           </p>
#          </dd>
#          <dt>
# ...
#           </a>
#          </li>
#          <li>
#           <a href="/admin" title="ADMINISTRATOR STAGE">
#            アドミニストレータ
#           </a>
#          </li>
#          <li>
#           <a href="/design" title="WEB+DESIGN STAGE">
#            WEB+デザイン
#           </a>
#          </li>
#          <li>
#           <a href="/lifestyle" title="LIFESTYLE STAGE">
#            ライフスタイル
#           </a>
#          </li>
#          <li>
#           <a href="/science" title="SCIENCE STAGE">
#            サイエンス
#           </a>
#          </li>
#          <li>
#           <a href="/news" title="NEWS &amp; REPORT">
#            ニュース&amp;レポート
#           </a>
#          </li>
#         </ul>
#        </div>
#        <div class="section">
#         <h2>
#          <a href="/book">
#           書籍案内
#          </a>
#         </h2>
#         <ul class="level01">
#          <li>
#           <a href="/book/list" title="新刊書籍">
#            新刊書籍
#           </a>
#          </li>
#          <li>
#           <a href="/book/genre" title="書籍ジャンル一覧">
#            書籍ジャンル一覧
#           </a>
#          </li>
#          <li>
#           <a href="/book/series" title="書籍シリーズ一覧">
#            書籍シリーズ一覧
#           </a>
#          </li>
#          <li>
#           <a href="/book/pickup" title="新刊ピックアップ">
#            新刊ピックアップ
#           </a>
#          </li>
#          <li>
#           <a href="/book/longseller" title="ロングセラー">
#            ロングセラー
#           </a>
#          </li>
#          <li>
#           <a href="/book/dennou" title="電脳会議">
#            電脳会議
#           </a>
#          </li>
#         </ul>
#        </div>
#        <div class="section">
#         <h2>
#          <a href="/magazine">
#           定期刊行物一覧
#          </a>
#         </h2>
#         <ul class="level01">
#          <li>
#           <a class="sd" href="/magazine/SD" title="Software Design">
#            Software Design
#           </a>
#          </li>
#          <li>
#           <a class="wdpress" href="/magazine/wdpress" title="WEB+DB PRESS">
#            WEB+DB PRESS
#           </a>
#          </li>
#         </ul>
#        </div>
#        <div class="section">
#         <h2>
#          <a href="https://direct.gihyo.jp" style="background-image: none;padding-left: 7px;" title="Gihyo Direct">
#           <img height="17" src="/assets/images/ICON/direct-icon.png" style="position:relative;top:11px;margin-right:4px;" width="24"/>
#           直販ストア
#          </a>
#         </h2>
#         <ul class="level01">
#          <li>
#           <a href="https://direct.gihyo.jp/view/news/list" title="ストアからのお知らせ">
#            お知らせ
#           </a>
#          </li>
#          <li>
#           <a href="https://direct.gihyo.jp/view/guide" title="ストアについてのヘルプ">
#            ご利用ガイド
#           </a>
#          </li>
#         </ul>
#        </div>
#        <div class="section">
#         <h2>
#          <a href="https://gihyo.jp/dp" style="background-image: none;padding-left: 7px;" title="Gihyo Digital Publishing">
#           <img height="24" src="/dp/assets/gdp-icon.png" style="position:relative;top:7px;margin-right:2px;" width="24"/>
#           電子書籍ストア
#          </a>
#         </h2>
#         <ul class="level01">
#          <li>
#           <a href="https://gihyo.jp/dp/information" title="ストアからのお知らせ">
#            お知らせ
#           </a>
#          </li>
#          <li>
#           <a href="https://gihyo.jp/dp/help" title="ストアについてのヘルプ">
#            ご購入方法・読み方
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#       <div class="sectionBlock01" id="recentTag">
#        <h2 class="bigBullet">
#         主なタグ
#        </h2>
#        <ul class="linkList01">
#         <li>
#          <a href="/tagList/Ubuntu" rel="tag">
#           Ubuntu
#          </a>
#         </li>
#         <li>
#          <a href="/tagList/FreeBSD" rel="tag">
#           FreeBSD
#          </a>
#         </li>
#         <li>
#          <a href="/tagList/Linux" rel="tag">
#           Linux
#          </a>
#         </li>
#         <li>
#          <a href="/tagList/Web%E3%83%87%E3%82%B6%E3%82%A4%E3%83%B3" rel="tag">
#           Webデザイン
#          </a>
#         </li>
#         <li>
#          <a href="/tagList/%E3%82%B9%E3%83%9E%E3%83%BC%E3%83%88%E3%83%95%E3%82%A9%E3%83%B3" rel="tag">
#           スマートフォン
#          </a>
#         </li>
#         <li>
#          <a href="/tagList/Android" rel="tag">
#           Android
#          </a>
#         </li>
#         <li>
#          <a href="/tagList/Web%E5%BA%83%E5%91%8A" rel="tag">
#           Web広告
#          </a>
#         </li>
#         <li>
#          <a href="/tagList/Web%E3%83%86%E3%82%AF" rel="tag">
#           Webテク
#          </a>
#         </li>
#        </ul>
#        <p class="linkParagraph02">
#         <a href="/tagList">
#          [ タグ一覧 ]
#         </a>
#        </p>
#       </div>
#       <div class="sectionBlock01" id="contentsRank">
#        <h2 class="bigBullet">
#         昨日よく読まれた記事
#        </h2>
#        <ul class="linkList01">
#         <li>
#          <a href="/admin/serial/01/ubuntu-recipe/0698">
#           第698回　デスクトップ環境の2021-2022年
#          </a>
#         </li>
#         <li>
#          <a href="/admin/clip/01/linux_dt/202201/06">
#           2022年1月6日　メモリ管理機能の「CleanCache」，Linuxメインラインから削除へ
#          </a>
#         </li>
#         <li>
#          <a href="/dev/serial/01/readers-forum/vol126">
#           WEB+DB PRESS Vol.125へのお便り
#          </a>
#         </li>
#         <li>
#          <a href="/dev/column/newyear/2022/carbon-neutral">
#           2022年，カーボンニュートラルへの動きがソフトウェア/ITシステムの世界にやってくる
#          </a>
#         </li>
#         <li>
#          <a href="/dev/column/newyear/2022/iot-tech-torends">
#           IoT活用で知っておきたい「2022年のIoT，3つのトレンド」
#          </a>
#         </li>
#         <li>
#          <a href="/admin/column/newyear/2022/quantum-computing">
#           “Quantum Ready”のその先へ ―2022年・量子コンピューティングの可能性
#          </a>
#         </li>
#         <li>
#          <a href="/news/info/2022/01/0601">
#           九州発Pythonイベント「PyCon Kyushu 2022 Kumamoto」1/22に開催
#          </a>
#         </li>
#         <li>
#          <a href="/dev/serial/01/oss-db-various-news/0077">
#           第77回　2021年北東アジアOSS貢献者賞と，MySQL ＆ PostgreSQLの2021年の主なニュース
#          </a>
#         </li>
#         <li>
#          <a href="/dev/column/newyear/2022/pwa-prospect">
#           Progressive Web Appsの振り返りとこれから
#          </a>
#         </li>
#         <li>
#          <a href="/lifestyle/clip/01/monthly-cat/202201/0106">
#           2022年1月6日　とっくに明けておりますが・・・
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </aside>
#    </div>
#    <footer role="contentinfo">
#     <div id="footer" itemscope="" itemtype="http://schema.org/WPFooter">
#      <div class="clearfix" id="footerContent">
#       <div id="information">
#        <h2>
#         <a href="/mail">
#          メールでのお知らせ
#         </a>
#        </h2>
#        <p>
#         メールで次の案内をお送りしております。メールの配信を希望する方は，利用したい項目をチェックしてメールアドレスを入力し，［登録］ボタンをクリックしてください。
#        </p>
#        <form action="/mail?mailregist#mailinfo" id="informationForm" method="post" name="informationForm">
#         <ul>
#          <li>
#           <input checked="checked" id="informationFormCheck00" name="gihyojp" type="checkbox" value="checked"/>
#           <label for="informationFormCheck00">
#            gihyo.jp UPDATES［ほぼ週間に1回］
#           </label>
#          </li>
#          <li>
#           <input checked="checked" id="informationFormCheck01" name="newPublished" type="checkbox" value="checked"/>
#           <label for="informationFormCheck01">
#            新刊メールマガジン［ほぼ週間に1回］
#           </label>
#          </li>
#          <li>
#           <input checked="checked" id="informationFormCheck02" name="dennou" type="checkbox" value="checked"/>
#           <label for="informationFormCheck02">
#            電脳会議の各号案内［ほぼ1ヵ月半に1回］
#           </label>
#          </li>
#         </ul>
#         <p class="submit">
#          <input autocapitalize="off" autocomplete="email" autocorrect="off" id="informationFormEmail" name="mailaddress" onblur="this.value=(this.value=='')? 'e-mailアドレスを入力' : this.value ;" onfocus="this.value=(this.value=='e-mailアドレスを入力')? '' : this.value ;" type="email" value="e-mailアドレスを入力"/>
#          <input class="submitButton" id="informationFormSubmit" type="submit" value="登録"/>
#         </p>
#        </form>
#        <p class="note">
#         ※変更する場合や停止する場合は，
#         <a href="/mail">
#          登録情報変更ページ
#         </a>
#         をご覧ください。
#        </p>
#        <p class="note">
#         ※登録いただいたメールアドレスには，そのお知らせ以外，配信いたしません。
#        </p>
#       </div>
#       <div id="siteSummary">
#        <h2>
#         <a href="/site">
#          このサイトについて
#         </a>
#        </h2>
#        <ul>
#         <li>
#          <a href="/site/profile">
#           会社案内
#          </a>
#         </li>
#         <li>
#          <a href="/site/policy">
#           プライバシーポリシー
#          </a>
#         </li>
#         <li>
#          <a href="/site/social">
#           ソーシャルメディアの運用について
#          </a>
#         </li>
#         <li>
#          <a href="/sales">
#           刊行物の購入について
#          </a>
#         </li>
#         <li>
#          <a href="/cmd">
#           カスタム出版・マーケティングのご案内
#          </a>
#         </li>
#         <li>
#          <a href="/site/inquiry">
#           お問い合わせ
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#      <div class="utility">
#       <ul class="logoIcon">
#        <li class="num01">
#         <a href="/magazine/SD" title="「Software Design」のトップページに移動">
#          <img alt="Software Design" class="buttons" height="21" src="/assets/templates/gihyojp2007/image/btn_icon_sd.gif" width="23"/>
#         </a>
#        </li>
#        <li class="num02">
#         <a href="/magazine/wdpress" title="「WEB+DB PRESS」のトップページに移動">
#          <img alt="WEB+DB PRESS" class="buttons" height="21" src="/assets/templates/gihyojp2007/image/btn_icon_wd.gif" width="23"/>
#         </a>
#        </li>
#       </ul>
#       <p class="feed">
#        <a href="/feed" title="gihyo.jpのフィードを確認">
#         RSS/ATOM
#        </a>
#       </p>
#       <p id="gotoHeader">
#        <a href="/#header">
#         このページの先頭へ
#        </a>
#       </p>
#      </div>
#      <div id="copyright">
#       <div class="logo">
#        <a href="http://www.gihyo.co.jp/">
#         <img alt="技術評論社" height="18" src="/assets/templates/gihyojp2007/image/gihyo_logo.png" width="113"/>
#        </a>
#       </div>
#       <p>
#        Copyright © 2007-2022 All Rights Reserved by Gijutsu-Hyoron Co., Ltd.
#        <br/>
#        ページ内容の全部あるいは一部を無断で利用することを禁止します。個別にライセンスが設定されている記事等はそのライセンスに従います。
#       </p>
#      </div>
#     </div>
#    </footer>
#   </div>
#   <script>
#    var o = document.querySelector('#primary .readingContent01');if(window.navigator.userAgent.toLowerCase().indexOf('android') > -1 && o){o.style.textAlign = 'left'}
#   </script>
#   <noscript>
#    <link href="/assets/templates/gihyojp2007/css/setAll0819.css" rel="stylesheet"/>
#   </noscript>
#   <script type="text/javascript">
#    var l=document.createElement('link');l.setAttribute('rel','stylesheet');l.setAttribute('type','text/css');l.setAttribute('media','all');l.setAttribute('href','/assets/templates/gihyojp2007/css/setAll0819.css');document.head.appendChild(l);l=null;
#   </script>
#   <script async="" src="/assets/js/lazysizes.min.js">
#   </script>
#   <script type="text/javascript">
#    $('#searchFormKeyword, #searchForm form').focus(function(e){this.value=(this.value=='検索したい用語を入力')?'':this.value;}).blur(function(e){this.value=(this.value=='')?'検索したい用語を入力':this.value;}).submit(function(e){this.value=(this.value=='検索したい用語を入力')?'':this.value;});
# function loadScript(src,callback){var e=document.createElement('script');if(e.readyState){e.onreadystatechange=function(){if(e.readyState=='loaded'||e.readyState=='complete'){e.onreadystatechange=null;callback();}};}else{e.onload=function(){callback();}};e.type='text/javascript';e.async=true;e.src=src;var s=document.getElementsByTagName('script')[0];s.parentNode.insertBefore(e,s);}
# loadScript('/assets/js/smoothscroll-min.js',function(){});
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'G-DL906V3TN7');
#   </script>
#   <script type="text/javascript">
#    (function(a){a("a img.buttons").hover(function(){this.originalSrc=a(this).attr("src");this.rolloverSrc=this.originalSrc.replace(/(_on)?(.gif|.jpg|.png)$/,"_on$2");this.rolloverImg=new Image;this.rolloverImg.src=this.rolloverSrc;a(this).attr("src",this.rolloverSrc)},function(){a(this).attr("src",this.originalSrc)})})(jQuery);
# (function(n){var m=new function(){for(var a="ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz0123456789+/".split(""),b=[],c=0;64>c;c++)b["ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz0123456789+/".charAt(c)]=c;this.encode=function(b,c){var d=c?l.unpackUTF8(b):l.unpackChar(b),i=d.length%3,h="",f,j=0;if(i)for(f=3-i;0<f;f--)d[d.length]=0;for(f=0;f<d.length;f+=3)j=d[f]<<16|d[f+1]<<8|d[f+2],h+=a[j>>>18&63]+a[j>>>12&63]+a[j>>>6&63]+a[j&63];if(i){i=3-i;for(h=h.substr(0,h.length-i);i--;)h+="="}return h};
# this.decode=function(a,c){var d;d=a.replace(/[^A-Za-z0-9\+\/]/g,"");var i=d.length%4,h,f,j,k=[];if(i)for(f=0;f<4-i;f++)d+="A";for(h=f=0;f<d.length;f+=4,h+=3)j=b[d.charAt(f)]<<18|b[d.charAt(f+1)]<<12|b[d.charAt(f+2)]<<6|b[d.charAt(f+3)],k[h]=j>>>16,k[h+1]=j>>>8&255,k[h+2]=j&255;i&&(k.length-=[0,0,2,1][i]);return c?l.packUTF8(k):l.packChar(k)}},l=new function(){this.unpackUTF16=function(a){var b,c=[];for(b=0;b<a.length;b++)c[b]=a.charCodeAt(b);return c};this.unpackChar=function(a){var a=this.unpackUTF16(a),
# b,c,e=[];for(c=b=0;b<a.length;b++)255>=a[b]?e[c++]=a[b]:(e[c++]=a[b]>>8,e[c++]=a[b]&255);return e};this.packChar=this.packUTF16=function(a){var b,c="";for(b in a)c+=String.fromCharCode(a[b]);return c};this.unpackUTF8=function(a){return this.toUTF8(this.unpackUTF16(a))};this.packUTF8=function(a){return this.packUTF16(this.toUTF16(a))};this.toUTF8=function(a){var b=[],c=0,e,g,d;for(e=0;e<a.length;e++)if(d=a[e],127>=d)b[c++]=d;else if(2047>=d)b[c++]=192|d>>>6,b[c++]=128|d&63;else if(65535>=d)b[c++]=
# 224|d>>>12,b[c++]=128|d>>>6&63,b[c++]=128|d&63;else{for(g=4;d>>6*g;)g++;for(b[c++]=65280>>>g&255|d>>>6*--g;g--;)b[c++]=128|d>>>6*g&63}return b};this.toUTF16=function(a){var b=[],c=0,e,g;for(e=0;e<a.length;e++,c++)if(127>=a[e])b[c]=a[e];else if(6==a[e]>>5)b[c]=(a[e]&31)<<6|a[++e]&63;else if(14==a[e]>>4)b[c]=(a[e]&15)<<12|(a[++e]&63)<<6|a[++e]&63;else{for(g=1;a[e]&32>>>g;)g++;for(b[c]=a[e]&31>>>g;0<=g--;)b[c]=b[c]<<6^a[++e]&63}return b};this.URLencode=function(a){return a.replace(/([^a-zA-Z0-9_\-\.])/g,
# function(a,c){if(" "==c)return"+";var e=l.toUTF8([c.charCodeAt(0)]),g="",d;for(d in e)d=e[d].toString(16),1==d.length&&(d="0"+d),g+="%"+d;return g})};this.URLdecode=function(a){a=a.replace(/\+/g," ");a=a.replace(/%([a-fA-F0-9][a-fA-F0-9])/g,function(a,c){return String.fromCharCode(parseInt(c,16))});return this.packChar(this.toUTF16(this.unpackUTF16(a)))}};n.extend({base64:{encode:m.encode,decode:m.decode,codec:"function"==typeof atob?"builtin":"alternate"}})})(jQuery);
# window.onerror=function(mes,fname,lnum){var erIgnore=['top.GLOBALS','originalCreateNotification','canvas.contentDocument','fb_xd_fragment','Script error.'];for(i=0;i<erIgnore.length;i++){if(mes.indexOf(erIgnore[i])>-1){return false;}};var mes='message:'+mes+', file:'+fname+', line:'+lnum+', href:'+location.href+', UA:'+window.navigator.userAgent;gtag('event','JSError',{'event_category':'Error','event_label':mes});};
# if (typeof(gtag) !== 'undifined') {
#   obj = document.querySelectorAll('.storeLink01 a');
#   for (k in obj) {
#     if (isNaN(k)) continue;
#     a = obj[k];
#     a.addEventListener('click', function(e){
#       label = e.target.textContent;
#       gtag('event', 'page_view', {page_location: '/go-' + encodeURIComponent(label)});
#     });
#   }
# }
#   </script>
#   <script type="text/javascript">
#    var html = "<h2>イベント</h2>\n<ul class=\"linkList02\">\n";
# var array = {
# 'https://www.iij.ad.jp/dev/tech/tw2021/': 'SUlKIFRlY2huaWNhbFdFRUsgMjAyMe+8iDEvMTjvvZ4yMe+8iQ==',
# 'http://jasst.jp/symposium/jasst22tokyo.html': 'SmFTU1QmIzAzOTsyMiBUb2t5b++8iDMvMTAsIDEx77yJ',
# 'https://phperkaigi.jp/2022/': 'UEhQZXJLYWlnaSAyMDIy77yINC8544CcMTHvvIk=',
#
# };
# for(key in array){
#   var str = $.base64.decode(array[key], 1);
#   var tmp = str.match(/^(.+?)(（.+?）)$/);
#   if(tmp){
#     html = html + '<li><a href="' + key + '" rel="external">' + tmp[1] + '</a>' + tmp[2] + "</li>\n";
#   }
# }
# html = html + "</ul>";
# document.getElementById("eventInfo").innerHTML = html;
#   </script>
#  </body>
# </html>
